# %% [markdown]
# <a href="https://colab.research.google.com/github/satikurup/Pedestrian-behavior-trajectory-prediction/blob/master/trajectory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-65f07e81e169> in <module>()
# ----> 1 print(tf.__version__)
#
# NameError: name 'tf' is not defined

# %%
# !bash /content/download_models.sh
# Out:
# --2021-08-02 04:23:43--  https://aladdin-eax.inf.cs.cmu.edu/shares/diva_obj_detect_models/models/obj_coco_resnet50_partial_tfv1.15_1920x1080_rpn300.pb
# Resolving aladdin-eax.inf.cs.cmu.edu (aladdin-eax.inf.cs.cmu.edu)... 128.2.204.83
# Connecting to aladdin-eax.inf.cs.cmu.edu (aladdin-eax.inf.cs.cmu.edu)|128.2.204.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182400402 (174M)
# Saving to: ‘models_and_data/obj_model.pb’
#
# models_and_data/obj 100%[===================>] 173.95M  37.0MB/s    in 5.2s
#
# 2021-08-02 04:23:48 (33.3 MB/s) - ‘models_and_data/obj_model.pb’ saved [182400402/182400402]
#
# --2021-08-02 04:23:48--  https://next.cs.cmu.edu/data/072019_prepare_data/deeplabv3_xception_ade20k_train.pb
# Resolving next.cs.cmu.edu (next.cs.cmu.edu)... 128.2.220.9
# Connecting to next.cs.cmu.edu (next.cs.cmu.edu)|128.2.220.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 165849058 (158M)
# ...

# %%
pip install tensorflow-gpu==1.15.2
# Out:
# ...
#      |████████████████████████████████| 410.9 MB 31 kB/s
# ...
#      |████████████████████████████████| 503 kB 41.3 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 46.9 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7553 sha256=84a7b447d6888edb0495c4452bff6d8451a19ad13001e46176eff08a799887c3
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 1.14.0
#     Uninstalling tensorflow-estimator-1.14.0:
#       Successfully uninstalled tensorflow-estimator-1.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
# ...

# %%
# !bash /content/download_test_video.sh
# Out:
# --2021-08-02 04:24:26--  https://next.cs.cmu.edu/data/VIRAT_S_000008.short.mp4
# Resolving next.cs.cmu.edu (next.cs.cmu.edu)... 128.2.220.9
# Connecting to next.cs.cmu.edu (next.cs.cmu.edu)|128.2.220.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7691151 (7.3M)
# Saving to: ‘test/test_video.mp4’
#
# test/test_video.mp4 100%[===================>]   7.33M  10.5MB/s    in 0.7s
#
# 2021-08-02 04:24:28 (10.5 MB/s) - ‘test/test_video.mp4’ saved [7691151/7691151]

# %%
# !python code/inference/main.py test/test_videos.lst test/output --pred_vis_path test/visualization
# Out:
# Loading obj model...
# obj model loaded.
# Loading scene seg model...
# scene seg model loaded.
# Loading person appearance model...
# person appearance model loaded.
# Loading prediction model...
# prediction model loaded.
# 1. Getting video frames...
# 	Done.
# 2. Object detection & tracking...
#   0% 0/1 [00:23<?, ?it/s]
#   0% 0/75 [00:00<?, ?it/s]
#   1% 1/75 [00:12<15:17, 12.40s/it]
#   3% 2/75 [00:12<10:41,  8.78s/it]
#   4% 3/75 [00:13<07:29,  6.24s/it]
#   5% 4/75 [00:13<05:16,  4.46s/it]
#   7% 5/75 [00:13<03:44,  3.21s/it]
#   8% 6/75 [00:13<02:41,  2.33s/it]
#   9% 7/75 [00:14<01:57,  1.72s/it]
#  11% 8/75 [00:14<01:26,  1.29s/it]
#  12% 9/75 [00:14<01:05,  1.01it/s]
#  13% 10/75 [00:15<00:50,  1.27it/s]
#  15% 11/75 [00:15<00:40,  1.56it/s]
#  16% 12/75 [00:15<00:33,  1.86it/s]
#  17% 13/75 [00:16<00:28,  2.15it/s]
#  19% 14/75 [00:16<00:25,  2.39it/s]
#  20% 15/75 [00:16<00:23,  2.61it/s]
#  21% 16/75 [00:16<00:21,  2.81it/s]
#  23% 17/75 [00:17<00:19,  2.96it/s]
# ...

# %%
# !cd test/visualization

# %%
# %cd test/visualization
# Out:
# /content/test/visualization

# %%
# !ffmpeg -framerate 30.0 -i test_video/test_video_F_%08d.jpg test_video.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
pip install ffmpeg
# Out:
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6084 sha256=30c733d31bbcad2138b38394049f0821e54bc1fea6fe7b3e8a21ab669017e9d5
#   Stored in directory: /root/.cache/pip/wheels/64/80/6e/caa3e16deb0267c3cbfd36862058a724144e19fdb9eb03af0f
# Successfully built ffmpeg
# ...

# %%
# %tensorflow_version 2.x
# !pip uninstall -y tensorflow
# !pip install tensorflow-gpu==1.14.0
# Out:
# Found existing installation: tensorflow 2.5.0
# Uninstalling tensorflow-2.5.0:
#   Successfully uninstalled tensorflow-2.5.0
# ...
#      |████████████████████████████████| 377.1 MB 8.6 kB/s
# ...
#      |████████████████████████████████| 3.1 MB 42.6 MB/s
# ...
#      |████████████████████████████████| 488 kB 53.4 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Attempting uninstall: tensorflow-gpu
#     Found existing installation: tensorflow-gpu 2.0.0a0
#     Uninstalling tensorflow-gpu-2.0.0a0:
#       Successfully uninstalled tensorflow-gpu-2.0.0a0
# ...
